# %% [markdown]
# # Quelques exemples d'utilisation du module ***Mouvements***
#
# ## *Ce fichier_test vous permet :*
# * De tester des commandes
# * De tester les algorithmes

# %%
import matplotlib.pyplot as plt
from cmath import *
import numpy as numpy
import matplotlib.animation as animation
import matplotlib.patheffects as path_effects
from mouvements import *

# %% [markdown]
# ## <ins>EXEMPLE 1</ins> : créer l'image d'une séquence de mouvements $m_1,m_2,....$ à partir d'un point $A_0$ dans une direction $d_0 \in \{1,1j,-1,1j\}$
#
# Pour cet exemple on va créer l'image de la séquence $seg^2\, Gv_g \, seg^2 \, Gv_d$ à partir du point $A_0=0$ depuis la direction $d_0=1$ sur une grille $3 \times 3$

# %%
lmouv=2*[seg]+[Gvg]+2*[seg]+[Gvd] #Liste des mouvements

# %%
A0,d0=0,1 #Choix du couple (point/direction)

# %%
dessin(lmouv,A0,d0,ligne=3,colonne=3,A0_visible=True) #Lancer le dessin en précisant lignes/colonnes
# Note A0_visible=False par défaut

# %% [markdown]
# ## <ins>EXEMPLE 2</ins>  : Algorithme de la tortue

# %%
A0=1+4j #Point de départ
d0=-1j #direction de départ
l=5 # Nombre de lignes
c=3 #Nombre de colonnes
T=tortue(ligne=l,colonne=c,pt_inf_gauche=0,A0=A0,d0=d0,mouv_init=seg)
dessin(T.lmouv,A0,d0,ligne=l,colonne=c)

# %% [markdown]
# ## <ins>EXEMPLE 3</ins>  : Itération d'un motif, l'exemple du dessin "Peng"

# %% [markdown]
# * **Paramètres** :

# %%
l,c=3,3 # 3 lignes et 3 colonnes
A0=1+2j # Point de départ
d0=-1j # direction de départ

# %% [markdown]
# * **Le motif à itérer** :

# %%
m=[seg]+4*[vd]+[ipengd,vd,ipengg,vg,pbg]
dessin(m,A0,d0,l,c)

# %% [markdown]
# * **La liste des mouvements, quatre fois $m$** :

# %%
lmouv=4*m
dessin(lmouv,A0,d0,l,c)
