# %% [markdown]
# # Quelques exemples d'utilisation du module ***Mouvements***
#
# ## *Ce fichier_test vous permet :*
# * De tester des commandes
# * De tester les algorithmes

# %%
import matplotlib.pyplot as plt
from cmath import *
import numpy as numpy
import matplotlib.animation as animation
import matplotlib.patheffects as path_effects
from mouvements import *

# %% [markdown]
# ## <ins>EXEMPLE 1</ins> : créer l'image d'une séquence de mouvements $m_1,m_2,....$ à partir d'un point $A_0$ dans une direction $d_0 \in \{1,1j,-1,1j\}$
#
# Pour cet exemple on va créer l'image de la séquence $seg^2\, Gv_g \, seg^2 \, Gv_d$ à partir du point $A_0=0$ depuis la direction $d_0=1$ sur une grille $3 \times 3$

# %%
lmouv=2*[seg]+[Gvg]+2*[seg]+[Gvd] #Liste des mouvements

# %%
A0,d0=0,1 #Choix du couple (point/direction)

# %%
dessin(lmouv,A0,d0,ligne=3,colonne=3,A0_visible=True) #Lancer le dessin en précisant lignes/colonnes
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.7/site-packages/matplotlib/axes/_axes.py in _parse_scatter_color_args(c, edgecolors, kwargs, xshape, yshape, get_next_color_func)
#    4284             try:  # Then is 'c' acceptable as PathCollection facecolors?
# -> 4285                 colors = mcolors.to_rgba_array(c)
#    4286                 n_elem = colors.shape[0]
#
# ~/opt/anaconda3/lib/python3.7/site-packages/matplotlib/colors.py in to_rgba_array(c, alpha)
#     293     for i, cc in enumerate(c):
# --> 294         result[i] = to_rgba(cc, alpha)
#     295     return result
#
# ~/opt/anaconda3/lib/python3.7/site-packages/matplotlib/colors.py in to_rgba(c, alpha)
#     176     if rgba is None:  # Suppress exception chaining of cache lookup failure.
# --> 177         rgba = _to_rgba_no_colorcycle(c, alpha)
#     178         try:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/matplotlib/colors.py in _to_rgba_no_colorcycle(c, alpha)
#     232             pass
# --> 233         raise ValueError("Invalid RGBA argument: {!r}".format(orig_c))
#     234     # tuple color.
#
# ValueError: Invalid RGBA argument: 'lawgngreen'
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-28-7b628a5031e9> in <module>
# ----> 1 dessin(lmouv,A0,d0,ligne=3,colonne=3,A0_visible=True) #Lancer le dessin en précisant lignes/colonnes
#
# ~/Google Drive/Thèse/Github/Thesis/mouvements.py in dessin(lmouv, A0, d0, ligne, colonne, N, epaisseur, couleur, A0_visible, d0_visible)
#     966     grille(l,c)
#     967     if A0_visible==True:
# --> 968         plt.scatter([A0.real], [A0.imag],c = ['lawngreen'],s = [110],marker = 'o')
#     969     ax.grid(False) #quadrillage
#     970     ax.axis([-2,c+2,-2,l+2]) #on fixe les xmin,xmax,ymin,ymax
#
# ~/opt/anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, plotnonfinite, data, **kwargs)
#    2845         verts=verts, edgecolors=edgecolors,
#    2846         plotnonfinite=plotnonfinite, **({"data": data} if data is not
# -> 2847         None else {}), **kwargs)
#    2848     sci(__ret)
#    2849     return __ret
#
# ~/opt/anaconda3/lib/python3.7/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1599     def inner(ax, *args, data=None, **kwargs):
#    1600         if data is None:
# -> 1601             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1602
#    1603         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/matplotlib/axes/_axes.py in scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, plotnonfinite, **kwargs)
#    4452             self._parse_scatter_color_args(
#    4453                 c, edgecolors, kwargs, xshape, yshape,
# -> 4454                 get_next_color_func=self._get_patches_for_fill.get_next_color)
#    4455
#    4456         if plotnonfinite and colors is None:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/matplotlib/axes/_axes.py in _parse_scatter_color_args(c, edgecolors, kwargs, xshape, yshape, get_next_color_func)
#    4304                         "'c' argument must be a mpl color, a sequence of mpl "
#    4305                         "colors or a sequence of numbers, not {}."
# -> 4306                             .format(c)  # note: could be long depending on c
#    4307                     )
#    4308         else:
#
# ValueError: 'c' argument must be a mpl color, a sequence of mpl colors or a sequence of numbers, not ['lawgngreen'].

# %% [markdown]
# ## <ins>EXEMPLE 2</ins>  : Algorithme de la tortue

# %%
A0=1+4j #Point de départ
d0=-1j #direction de départ
l=5 # Nombre de lignes
c=3 #Nombre de colonnes
T=tortue(ligne=l,colonne=c,pt_inf_gauche=0,A0=A0,d0=d0,mouv_init=seg)
dessin(T.lmouv,A0,d0,ligne=l,colonne=c)
